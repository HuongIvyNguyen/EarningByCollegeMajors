# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline 

recent_grads = pd.read_csv("recent-grads.csv")
first_row = recent_grads.iloc[0]
print(first_row)
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Major_category                    Engineering
# Total                                    2339
# Sample_size                                36
# Men                                      2057
# Women                                     282
# ShareWomen                           0.120564
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
print(recent_grads.head())
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2405                       CHEMICAL ENGINEERING    Engineering
#
#    Total  Sample_size    Men  Women  ShareWomen  Employed      ...        \
# 0   2339           36   2057    282    0.120564      1976      ...
# 1    756            7    679     77    0.101852       640      ...
# 2    856            3    725    131    0.153037       648      ...
# 3   1258           16   1123    135    0.107313       758      ...
# 4  32260          289  21239  11021    0.341631     25694      ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
print(recent_grads.tail())
# Out:
#      Rank  Major_code                   Major            Major_category  \
# 168   169        3609                 ZOOLOGY    Biology & Life Science
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  Psychology & Social Work
# 170   171        5202     CLINICAL PSYCHOLOGY  Psychology & Social Work
# 171   172        5203   COUNSELING PSYCHOLOGY  Psychology & Social Work
# 172   173        3501         LIBRARY SCIENCE                 Education
#
#      Total  Sample_size   Men  Women  ShareWomen  Employed      ...        \
# 168   8409           47  3050   5359    0.637293      6259      ...
# 169   2854            7   522   2332    0.817099      2125      ...
# 170   2838           13   568   2270    0.799859      2101      ...
# 171   4626           21   931   3695    0.798746      3777      ...
# 172   1098            2   134    964    0.877960       742      ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
print(recent_grads.describe())
# Out:
#              Rank   Major_code          Total  Sample_size            Men  \
# count  173.000000   173.000000     173.000000   173.000000     173.000000
# mean    87.000000  3879.815029   39167.716763   356.080925   16637.358382
# std     50.084928  1687.753140   63354.613919   618.361022   28063.394844
# min      1.000000  1100.000000     124.000000     2.000000     119.000000
# 25%     44.000000  2403.000000    4361.000000    39.000000    2110.000000
# 50%     87.000000  3608.000000   15058.000000   130.000000    5347.000000
# 75%    130.000000  5503.000000   38844.000000   338.000000   14440.000000
# max    173.000000  6403.000000  393735.000000  4212.000000  173809.000000
#
#                Women  ShareWomen       Employed      Full_time      Part_time  \
# count     173.000000  173.000000     173.000000     173.000000     173.000000
# mean    22530.358382    0.522550   31192.763006   26029.306358    8832.398844
# ...

# %%
#Generating scatter plot between sample_size and median
ax1=recent_grads.plot(x="Sample_size",y="Median",kind='scatter')
ax1.set(title='Sample size versus Median',xlabel='Sample_size',ylabel='Median')
plt.show()

# %%
#Generating scatter plot between sample_size and Unemployment_rate
ax2=recent_grads.plot(x="Sample_size",y="Unemployment_rate",kind='scatter')
ax2.set(title='Sample size versus Unemployment Rate',xlabel='Sample_size',ylabel='Unemployment rate')
plt.show()

# %%
#Generating scatter plot between Full time and Median
ax3=recent_grads.plot(x="Full_time",y="Median",kind='scatter')
ax3.set(title='Full time versus Median',xlabel='Full_time',ylabel='Median')
plt.show()

# %%
#Generating scatter plot between ShareWomen and Unemployment_rate
ax4=recent_grads.plot(x="ShareWomen",y="Unemployment_rate",kind='scatter')
ax4.set(title='ShareWomen versus Unemployment Rate',xlabel='ShareWomen',ylabel='Unemployment rate')
plt.show()

# %%
#Generating scatter plot between Men and Median
ax5=recent_grads.plot(x="Men",y="Median",kind='scatter')
ax5.set(title='Men versus Median',xlabel='Men',ylabel='Median')
plt.show()

# %%
#Generating scatter plot between Women and Median
ax6=recent_grads.plot(x="Women",y="Median",kind='scatter')
ax6.set(title='Women versus Median',xlabel='Women',ylabel='Median')
plt.show()

# %% [markdown]
# ## Generate histograms for Sample_size, Median, Employed, Full_time, ShareWomen, Unemployment_rate, Men, Women

# %%
list_to_graph = ["Sample_size",'Median','Employed','Full_time','ShareWomen','Unemployment_rate','Men','Women']
for i in list_to_graph:
    ax = recent_grads[i].hist()
    ax.set(title= 'histogram of '+ i,xlabel=i,ylabel='Frequency')
    plt.show()

# %%
from pandas.tools.plotting import scatter_matrix 
scatter_matrix(recent_grads[['Sample_size','Median']])
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']])
plt.show()

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)
recent_grads[163:].plot.bar(x='Major', y='ShareWomen', legend=False)

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate', legend=False)
recent_grads[163:].plot.bar(x='Major', y='Unemployment_rate', legend=False)
